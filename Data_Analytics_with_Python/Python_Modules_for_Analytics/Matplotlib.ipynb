# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Subplots

# %%
x = range(10)
y = range(10)
fig, ax = plt.subplots(nrows = 2, ncols = 3,
                      sharex = True, sharey = True
                      )
for row in ax:
    for col in row:
        col.plot(x, y)

plt.show()
